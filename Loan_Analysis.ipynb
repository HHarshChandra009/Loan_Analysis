# %%
import pandas as pd
import numpy as np

# %%
dd = pd.read_excel("Data_Dictionary (1).xlsx")
dd.head()
# Out:
#             LoanStatNew                                        Description
# 0        acc_now_delinq  The number of accounts on which the borrower i...
# 1  acc_open_past_24mths         Number of trades opened in past 24 months.
# 2            addr_state  The state provided by the borrower in the loan...
# 3              all_util              Balance to credit limit on all trades
# 4            annual_inc  The self-reported annual income provided by th...

# %%
dd
# Out:
#                LoanStatNew                                        Description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 112    verification_status  Indicates if income was verified by LC, not ve...
# 113  verified_status_joint  Indicates if the co-borrowers' joint income wa...
# 114               zip_code  The first 3 numbers of the zip code provided b...
# 115                    NaN                                                NaN
# 116                    NaN  * Employer Title replaces Employer Name for al...
#
# [117 rows x 2 columns]

# %%
dd.dropna()
dd.head(50)
# Out:
#                    LoanStatNew  \
# 0               acc_now_delinq
# 1         acc_open_past_24mths
# 2                   addr_state
# 3                     all_util
# 4                   annual_inc
# 5             annual_inc_joint
# 6             application_type
# 7                  avg_cur_bal
# 8               bc_open_to_buy
# 9                      bc_util
# 10    chargeoff_within_12_mths
# 11     collection_recovery_fee
# 12  collections_12_mths_ex_med
# 13                 delinq_2yrs
# 14                 delinq_amnt
# 15                        desc
# 16                         dti
# 17                   dti_joint
# 18            earliest_cr_line
# 19                  emp_length
# 20                   emp_title
# 21             fico_range_high
# 22              fico_range_low
# 23                 funded_amnt
# 24             funded_amnt_inv
# 25                       grade
# 26              home_ownership
# 27                          id
# 28                     il_util
# ...

# %%
dd.tail(50)
# Out:
#                     LoanStatNew  \
# 67          num_rev_tl_bal_gt_0
# 68                     num_sats
# 69             num_tl_120dpd_2m
# 70                 num_tl_30dpd
# 71           num_tl_90g_dpd_24m
# 72           num_tl_op_past_12m
# 73                     open_acc
# 74                  open_acc_6m
# 75                  open_il_12m
# 76                  open_il_24m
# 77                   open_il_6m
# 78                  open_rv_12m
# 79                  open_rv_24m
# 80                    out_prncp
# 81                out_prncp_inv
# 82               pct_tl_nvr_dlq
# 83             percent_bc_gt_75
# 84                  policy_code
# 85                      pub_rec
# 86         pub_rec_bankruptcies
# 87                      purpose
# 88                   pymnt_plan
# 89                   recoveries
# 90                    revol_bal
# 91                   revol_util
# 92                    sub_grade
# 93                    tax_liens
# 94                         term
# ...

# %%
ds = pd.read_csv("loan.csv")
# Out:
# <ipython-input-7-85d6f9d96ea5>:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv("loan.csv")

# %%
ds.tail(40)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39677  113194     113115       3500         3500           1725.0   36 months
# 39678  113179     113093       1000         1000            950.0   36 months
# 39679  113156     113146       3500         3500           3500.0   36 months
# 39680  112496     112493       3000         3000            525.0   36 months
# 39681  112323     107671       3500         3500           1125.0   36 months
# 39682   99009      98991       5750         5750           3675.0   36 months
# 39683  112245     112227       5000         5000           3975.0   36 months
# 39684  112216     106279      12000        12000           1025.0   36 months
# 39685  100214     100208       5000         5000           3675.0   36 months
# 39686  111917     111912       6400         6400           4075.0   36 months
# 39687  111307     105982      12000        12000           2500.0   36 months
# ...

# %%
ds.shape
# Out:
# (39717, 111)

# %%
newds= ds
newds.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
newds['result'] = (ds['installment']/(ds['annual_inc']/12))*100
newds['monthly_income'] = ds['annual_inc']/12
newds[['verification_status','loan_amnt','emp_length','monthly_income','installment','result']]
newds.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... pct_tl_nvr_dlq percent_bc_gt_75  \
# 0   10.65%       162.87     B        B2  ...            NaN              NaN
# 1   15.27%        59.83     C        C4  ...            NaN              NaN
# 2   15.96%        84.33     C        C5  ...            NaN              NaN
# 3   13.49%       339.31     C        C1  ...            NaN              NaN
# 4   12.69%        67.79     B        B5  ...            NaN              NaN
#
# ...

# %%
newds1 = newds[newds['result'] > 10]
newds1.shape
# Out:
# (7369, 113)

# %%
newds1 = newds1[['verification_status','loan_amnt','emp_length','monthly_income','installment','result']]
#newds2 = newds1[newds1['chargeoff_within_12_mths'] > 0.0]

# %%
newds1.head()
# Out:
#    verification_status  loan_amnt emp_length  monthly_income  installment  \
# 12     Source Verified       9000   < 1 year     2500.000000       305.38
# 20            Verified      20250    3 years     3614.166667       484.63
# 26        Not Verified      15000    9 years     5000.000000       514.64
# 29     Source Verified       8500   < 1 year     2083.333333       281.15
# 31            Verified      31825    5 years     6250.000000       995.82
#
#        result
# 12  12.215200
# 20  13.409177
# 26  10.292800
# 29  13.495200
# 31  15.933120

# %%
newds1[newds1['verification_status']=='Not Verified'].shape
# Out:
# (2486, 6)

# %%
newds1[newds1['emp_length']=='1 year'].shape
# Out:
# (611, 4)

# %%
newds1[newds1['emp_length']=='< 1 year'].shape
# Out:
# (878, 4)

# %% [markdown]
# The customers with installment higher than 20% of their monthly income are high risk and are more likely to default.

# %%
newds1[newds1['emp_length']=='2 years'].shape
# Out:
# (850, 4)

# %% [markdown]
# The customers with employment length less than 2 years and emi higher than 10% of monthly income can default, that makes the figure to 2339

# %% [markdown]
# So in Total, I would say there could be 3 major factors, emi percentage of monthly income, Emp_length and Income Source 'Not Verified'.

# %%
df = newds
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... pct_tl_nvr_dlq percent_bc_gt_75  \
# 0   10.65%       162.87     B        B2  ...            NaN              NaN
# 1   15.27%        59.83     C        C4  ...            NaN              NaN
# 2   15.96%        84.33     C        C5  ...            NaN              NaN
# 3   13.49%       339.31     C        C1  ...            NaN              NaN
# 4   12.69%        67.79     B        B5  ...            NaN              NaN
#
# ...

# %% [markdown]
# Here we will display the data of those customers who have result ratio of greater than 10 and income source not verified, and have employment length less than or equal to 2 years, these **could be** highest degree of potential defaulters

# %%
display(df.loc[(df['verification_status']=='Not Verified') & (df['result']>10) & ((df['emp_length']=='2 years')|(df['emp_length']=='1 year')|(df['emp_length']=='<1 year'))])
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 54     1069238    1303909      12000        12000     12000.000000
# 78     1068997    1303437      15000        15000     15000.000000
# 140    1061304    1293317      15000        15000     15000.000000
# 145    1068091    1302450      12000        12000     12000.000000
# 157    1067109    1301487       8500         8500      8500.000000
# ...        ...        ...        ...          ...              ...
# 39584   144635     144623      25000        25000      3724.990259
# 39602   139968     139887      10000        10000      2175.000000
# 39629   131387     113921       6000         6000       600.000000
# 39666   119043     119040      15450        15450       600.000000
# 39696   102376      95212      25000        25000       525.000000
#
#              term int_rate  installment grade sub_grade  ... pct_tl_nvr_dlq  \
# 54      36 months    9.91%       386.70     B        B1  ...            NaN
# ...
